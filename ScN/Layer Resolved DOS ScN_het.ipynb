# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# %%
test = !grep -A 1200 "\-1.270" /home/nadamski/ScNhex_LayerDOS/GaSc88_25_hex/minus/Ga8Sc8_hex_HSE_DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1202:S*1202+1201]]) for S in range(33)]

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = 'br'

E = atoms[0][:,0] -5.0332
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*AT-2
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-2, 35], 'k-.', alpha=0.6)

plt.title('Layer resolved Density of States for GaN-h/ScN-h', fontsize=16)
ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

ax.text(-6.0, -3, 'GaN', color='blue', fontsize=16)
ax.text(-6.0, 33, 'ScN', color='mediumvioletred', fontsize=16)
ax.text(0.2, 33, r'$E_F$', color='k', fontsize=16)

plt.savefig('/home/nadamski/ScNhex_LayerDOS/GaSc88_25_hex/88_layerDOS_hex.png', bbox_inches='tight', format='png', dpi=300)


plt.show()

# %%
test = !grep -A 1200 "\-0.504" /home/nadamski/ScNhex_LayerDOS/minus/Ga8Sc8_0012_PBE_DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1202:S*1202+1201]]) for S in range(33)]

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = 'br'

E = atoms[0][:,0] -4.9058
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*AT-2
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-2, 35], 'k-.', alpha=0.3)

plt.title('Layer resolved Density of States for GaN-h/ScN-0.012', fontsize=16)
ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

ax.text(-5.0, -3, 'GaN', color='r', fontsize=16)
ax.text(-5.0, 33, 'ScN', color='b', fontsize=16)
ax.text(0.2, 33, r'$E_F$', color='k', fontsize=16)


plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-3-5a265c2e080e> in <module>
#       1 test = get_ipython().getoutput('grep -A 1200 "\\-0.504" /home/nadamski/ScNhex_LayerDOS/minus/Ga8Sc8_0012_PBE_DOSCAR')
# ----> 2 atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1202:S*1202+1201]]) for S in range(33)]
#       3
#       4 fig = plt.figure(figsize=(6,4))
#       5 ax = plt.subplot(111)
#
# <ipython-input-3-5a265c2e080e> in <listcomp>(.0)
#       1 test = get_ipython().getoutput('grep -A 1200 "\\-0.504" /home/nadamski/ScNhex_LayerDOS/minus/Ga8Sc8_0012_PBE_DOSCAR')
# ----> 2 atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1202:S*1202+1201]]) for S in range(33)]
#       3
#       4 fig = plt.figure(figsize=(6,4))
#       5 ax = plt.subplot(111)
#
# <ipython-input-3-5a265c2e080e> in <listcomp>(.0)
# ...

# %%
test = !grep -A 1200 "\-1.672" /home/nadamski/ScNhex_LayerDOS/GaSc68_25/Ga6Sc8_bulk_HSE25_DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1202:S*1202+1201]]) for S in range(33)]

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = 'br'

E = atoms[0][:,0] -5.2311
for AT in range(1,15):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[14+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 7])
plt.plot([0, 0], [-2, 35], 'k-.', alpha=0.3)

plt.title('Layer resolved Density of States for GaN/ScN', fontsize=16)
ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

ax.text(-5.0, -3, 'GaN', color='r', fontsize=16)
ax.text(-5.0, 33, 'ScN', color='b', fontsize=16)
ax.text(0.2, 33, r'$E_F$', color='k', fontsize=16)

plt.savefig('/home/nadamski/ScNhex_LayerDOS/GaSc68_25/68_layerDOS.png', bbox_inches='tight', format='png', dpi=300)


plt.show()

# %%
np.sum(a,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-c1f62e685935> in <module>
# ----> 1 np.sum(a,0)
#
# NameError: name 'a' is not defined

# %%
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-3f786850e387> in <module>
# ----> 1 a
#
# NameError: name 'a' is not defined

# %%
test = !grep -A 1200 "\-1.694" /home/nadamski/SupLatPots/Ga8Sc8/strained/HSE00/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1202:S*1202+1201]]) for S in range(33)]

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = ['mediumvioletred', 'blue']

E = atoms[0][:,0] -4.9873
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-2, 35], 'k-.', alpha=0.6)
plt.ylim([-0.0, 33])

#plt.title(r'GaN/ScN $u_m = 0$', fontsize=16)
ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

#ax.text(-6.0, -3, 'GaN', color='blue', fontsize=16)
#ax.text(-6.0, 33, 'ScN', color='mediumvioletred', fontsize=16)
ax.text(0.2, 30.6, r'$E_F$', color='k', fontsize=16)

plt.savefig('/home/nadamski/SupLatPots/Ga8Sc8/strained/HSE00/88_strainedDOS.png', bbox_inches='tight', format='png', dpi=300)


plt.show()

# %%
test = !grep -A 1200 "\-1.596" /home/nadamski/SupLatPots/Ga8Sc8/strained/HSE_245/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1202:S*1202+1201]]) for S in range(33)]

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = ['mediumvioletred', 'blue']

E = atoms[0][:,0] -4.3967
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-2, 35], 'k-.', alpha=0.6)
plt.ylim([-0.0, 33])
#plt.title(r'GaN/ScN $u_m = 0.25$', fontsize=16)
ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

#ax.text(-6.0, -3, 'GaN', color='blue', fontsize=16)
#ax.text(-6.0, 33, 'ScN', color='mediumvioletred', fontsize=16)
ax.text(0.2, 30.6, r'$E_F$', color='k', fontsize=16)

plt.savefig('/home/nadamski/SupLatPots/Ga8Sc8/strained/HSE_245/88_245DOS.png', bbox_inches='tight', format='png', dpi=300)


plt.show()

# %%
test = !grep -A 1200 "\-1.596" /home/nadamski/SupLatPots/Ga8Sc8/strained/HSE_245_new/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1202:S*1202+1201]]) for S in range(33)]

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = ['mediumvioletred', 'blue']

E = atoms[0][:,0] -4.3967
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-2, 35], 'k-.', alpha=0.6)

#plt.title(r'GaN/ScN $u_m = 0.25$', fontsize=16)
ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

ax.text(-6.0, -3, 'GaN', color='blue', fontsize=16)
ax.text(-6.0, 33, 'ScN', color='mediumvioletred', fontsize=16)
ax.text(0.2, 33, r'$E_F$', color='k', fontsize=16)

plt.savefig('/home/nadamski/SupLatPots/Ga8Sc8/strained/HSE_245/88_245DOS.png', bbox_inches='tight', format='png', dpi=300)


plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-9-07ebfa21652e> in <module>
#       6 colors = ['mediumvioletred', 'blue']
#       7
# ----> 8 E = atoms[0][:,0] -4.3967
#       9 for AT in range(1,17):
#      10     DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
#
# IndexError: too many indices for array

# %%
test = !grep -A 1200 "\-1.596" /home/nadamski/SupLatPots/Ga8Sc8/strained/HSE_25/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1202:S*1202+1201]]) for S in range(33)]

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = ['mediumvioletred', 'blue']

E = atoms[0][:,0] -4.3349
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-2, 35], 'k-.', alpha=0.3)

plt.title(r'GaN/ScN $u_m = 0.25$', fontsize=16)
ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

ax.text(-6.0, -3, 'GaN', color='blue', fontsize=16)
ax.text(-6.0, 33, 'ScN', color='mediumvioletred', fontsize=16)
ax.text(0.2, 33, r'$E_F$', color='k', fontsize=16)

plt.savefig('/home/nadamski/SupLatPots/Ga8Sc8/strained/HSE_25/88_25DOS.png', bbox_inches='tight', format='png', dpi=300)


plt.show()

# %%
test = !grep -A 1200 "\-1.534" /home/nadamski/SupLatPots/Ga8Sc8/strained/HSE_bulk/DOS16/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1202:S*1202+1201]]) for S in range(33)]

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = ['mediumvioletred', 'blue']

E = atoms[0][:,0] -4.9873
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-4, 41], 'k-.', alpha=0.6)

#plt.title('GaN/ScN bulk interface', fontsize=16)
ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

#ax.text(-6.0, -4, 'GaN', color='blue', fontsize=16)
#ax.text(-6.0, 38, 'ScN', color='mediumvioletred', fontsize=16)
ax.text(-1.2, 33, r'$E_F$', color='k', fontsize=16)
plt.ylim([0, 36])

plt.savefig('/home/nadamski/SupLatPots/Ga8Sc8/strained/HSE_bulk/DOS16/88_bulkDOS.png', bbox_inches='tight', format='png', dpi=300)


plt.show()

# %%
test = !grep -A 1200 "\-1.534" /home/nadamski/SupLatPots/Ga8Sc8/strained/HSE_bulk/DOS16/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1202:S*1202+1201]]) for S in range(33)]

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = 'br'

E = atoms[0][:,0] -4.9873
for AT in {1}:
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)
    plt.plot(E,2*DOS, colors[AT < 9])
plt.plot([0, 0], [0, 40], 'k-.', alpha=0.3)

#plt.title('GaN/ScN bulk interface', fontsize=16)

plt.xlim([-0.6, 0])

plt.ylim([0, 3])
ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
ax.xaxis.set_major_formatter(mtick.FormatStrFormatter('%.2f'))

plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

#ax.text(-5.0, -3, 'GaN', color='r', fontsize=16)
#ax.text(-5.0, 37, 'ScN', color='b', fontsize=16)
ax.text(-1.2, 3, r'$E_F$', color='k', fontsize=16)


plt.show()

# %%
DOS[300:400]
# Out:
# array([0.0320665 , 0.0319126 , 0.0317743 , 0.0315272 , 0.0314731 ,
#        0.0314377 , 0.0314158 , 0.0314456 , 0.0314167 , 0.0313916 ,
#        0.0313428 , 0.0306227 , 0.0304931 , 0.0307986 , 0.0415301 ,
#        0.0398941 , 0.0381517 , 0.0363168 , 0.0345995 , 0.0326029 ,
#        0.0302376 , 0.0295068 , 0.0275399 , 0.0252908 , 0.0302761 ,
#        0.0271883 , 0.0274047 , 0.0255197 , 0.0219775 , 0.0201644 ,
#        0.0182617 , 0.0163295 , 0.0144683 , 0.0126394 , 0.01084367,
#        0.01067264, 0.01051302, 0.01034241, 0.01019219, 0.00962271,
#        0.00951781, 0.00944087, 0.00936562, 0.00931172, 0.00928077,
#        0.00952861, 0.00942168, 0.00938985, 0.00935958, 0.00934176,
#        0.0093153 , 0.00935303, 0.00936327, 0.00938806, 0.00942202,
#        0.00920482, 0.00898261, 0.00876356, 0.00917727, 0.00897615,
#        0.00871673, 0.00851916, 0.00901993, 0.00941683, 0.00910871,
#        0.00876589, 0.00762906, 0.00742716, 0.00725145, 0.00706453,
# ...

# %%
test = !grep -A 1200 "\-14.320" /home/nadamski/SupLatPots/Ga8Sc8/strained/HSE00/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1202:S*1202+1201]]) for S in range(33)]

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = 'br'

E = atoms[0][:,0] -4.9873
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    print(np.argmax(DOS[600:1100]))
    plt.plot(E,DOS, colors[AT < 9])
    
plt.title('Layer resolved Density of States for GaN/ScN', fontsize=16)
ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

ax.text(-5.0, -3, 'GaN', color='r', fontsize=16)
ax.text(-5.0, 33, 'ScN', color='b', fontsize=16)
ax.text(0.2, 33, r'$E_F$', color='k', fontsize=16)


plt.show()
# Out:
# 469
# 393
# 377
# 372
# 367
# 355
# 344
# 341
# 341
# 341
# 499
# 499
# 469
# 469
# 469
# 469

# %%
E[977]
# Out:
# -8.590300000000001

# %%
a = [416, 428, 447, 466, 485, 504, 523, 523]
b = [1069, 993, 977, 972, 967, 966, 944, 941]

# %%
E[a]
# Out:
# array([-14.7443, -14.6123, -14.4043, -14.1953, -13.9873, -13.7783,
#        -13.5703, -13.5703])

# %%
(E[523] - E[428]) / (5 * 2.2489140581064202*2*3**0.5/3*(1-0.0035823439613637213)) *1e10
# Out:
# 805404538.6712782

# %%
805404538.6712782 * 8.85e-12 * (2 + 8.9 + 24)
# Out:
# 0.24876127283670438

# %%
( 2.2489140581064202*2*3**0.5/3*(1-0.0035823439613637213))
# Out:
# 2.5875195630733554

# %%
(E[523] - E[428])
# Out:
# 1.0420000000000016

# %%
(3 * 2.2489140581064202*2*3**0.5/3*(1-0.0035823439613637213))
# Out:
# 7.762558689220065

# %%
test = !grep -A 1500 "2.838" /home/nadamski/SupLatPots/Ga10Sc11/strained/HSE00_2/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1502:S*1502+1501]]) for S in range(43)]
fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = 'br'

E = atoms[0][:,0] -4.9418
for AT in range(1,22):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[21+AT][:,1:],1)+2*AT-2
    plt.plot(E,DOS, colors[AT < 11])
plt.plot([0, 0], [-2, 35], 'k-.', alpha=0.3)

#plt.title('GaN/ScN bulk interface', fontsize=16)


ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
ax.xaxis.set_major_formatter(mtick.FormatStrFormatter('%.2f'))

plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

#ax.text(-5.0, -3, 'GaN', color='r', fontsize=16)
#ax.text(-5.0, 37, 'ScN', color='b', fontsize=16)


plt.show()

# %%
test = !grep -A 1200 "\-1.694" /home/nadamski/SupLatPots/Ga8Sc8/strained/HSE00/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1202:S*1202+1201]]) for S in range(33)]

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = ['mediumvioletred', 'blue']

E = atoms[0][:,0] -4.9873
for AT in range(1,9):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+Ga*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
    
for AT in range(9,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+Sc*(AT-9) + 8 * Ga
    plt.plot(E,DOS, colors[AT < 9])

plt.plot([0, 0], [-2, 45], '-.', color='k')
plt.ylim([-0.0, 45])

plt.plot(Ef_Ga+VB_Ga -Ef-a, [0, 8*Ga], 'blue')
plt.plot(Ef_Ga+CB_Ga -Ef-a, [0, 8*Ga], 'blue')

plt.plot(Ef_Sc+VB_Sc -Ef-a, [8*Ga, 8*Ga + 8*Sc],'mediumvioletred')
plt.plot(Ef_Sc+CB_Sc -Ef-a, [8*Ga, 8*Ga + 8*Sc],'mediumvioletred')


#plt.title(r'GaN/ScN $u_m = 0$', fontsize=16)
ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

#ax.text(-6.0, -3, 'GaN', color='blue', fontsize=16)
#ax.text(-6.0, 33, 'ScN', color='mediumvioletred', fontsize=16)
ax.text(0.2, 42, r'$E_F$', color='k', fontsize=16)

plt.savefig('/home/nadamski/test2.png', bbox_inches='tight', format='png', dpi=300)


plt.show()

# %%
Ga = 5.2000529025666484/2
Sc = 2.2489140581064202*2*3**0.5/3*(1-0.0035823439613637213)

Ef_Sc = np.array([-8.211386911003087, -6.5229426833150725])
Ef_Ga = np.array([-5.79018841503395, -6.4502166131301735])



VB_Sc = 4.838952
CB_Sc = 6.920244

VB_Ga = 2.415138
CB_Ga = 5.469289

Ef = 4.9873
a = -6.714105391571179

# %%
VB_GaN = 2.062341
CB_GaN = 5.245465

VB_ScN = 5.143874
CB_ScN = 6.042059

# %%
test = !grep -A 1200 "\-1.534" /home/nadamski/SupLatPots/Ga8Sc8/strained/HSE_bulk/DOS16/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1202:S*1202+1201]]) for S in range(33)]

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = ['mediumvioletred', 'blue']

E = atoms[0][:,0] -4.9873
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-4, 41], 'k-.', alpha=0.6)

V = np.array([-10.842013583737735, -5.6435402749274175, -8.489077268487053, -11.577845629247257])--9.130804538230752 - 4.9873


plt.plot(V[0:2]+VB_GaN, [0, 15], 'black')
plt.plot(V[0:2]+CB_GaN, [0, 15], 'black')

plt.plot(V[2:4]+VB_ScN, [15, 31], 'black')
plt.plot(V[2:4]+CB_ScN, [15, 31], 'black')


#plt.title('GaN/ScN bulk interface', fontsize=16)
ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

#ax.text(-6.0, -4, 'GaN', color='blue', fontsize=16)
#ax.text(-6.0, 38, 'ScN', color='mediumvioletred', fontsize=16)
ax.text(-1.2, 33, r'$E_F$', color='k', fontsize=16)
plt.ylim([0, 36])

plt.savefig('/home/nadamski/test_bulk.png', bbox_inches='tight', format='png', dpi=300)


plt.show()
