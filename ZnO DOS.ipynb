# %%
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

# %%
#HSE
Eg_Zn = 2.301416 - -0.161859 #Direct Gamma, agrees with https://journals.aps.org/prb/pdf/10.1103/PhysRevB.80.155124
Eg_Ca = 6.592634 - 1.273947 #Gamma -> X
Eg_Cd = 1.710666 - 0.853219 #L -> Gamma
Eg_Mg = 8.550397 - 1.992951 #Direct Gamma

# %%
Eg_Cd
# Out:
# 0.8574470000000001

# %%
3.2562112433332855 * 2**0.5
# Out:
# 4.604978102273691

# %%
a_Mg = 2.0996784416305903 * 2**0.5
c_Mg = 2.0996784416305903 * 3**0.5 * 2
c_Mg_on_Zn = 7.0101798638883475

a_Ca = 2.4038016181676580 *2**0.5
c_Ca = 2.4038016181676580 *3**0.5 * 2
c_Ca_on_Zn = 8.4973270615965415


a_Cd = 2.3614121609750778 *2**0.5
c_Cd = 2.3614121609750778 *3**0.5 * 2
c_Cd_on_Zn = 8.3518376319009864

a_Zn = 3.2562112433332855
c_Zn = 5.2436599575602845

e_Zn = 3.78 # https://www.vasp.at/mmars/day2.pdf
e_Mg = 2.94 # https://arxiv.org/pdf/1706.08159.pdf

e_clamp_Ca00 = 2.985
e_clamp_Ca50 = 3.316

e_clamp_Cd00 = 3.773
e_clamp_Cd50 = 5.153

e_clamp_Mg00 = 3.092
e_clamp_Mg50 = 2.910

e_clamp_Zn00 = 3.567
e_clamp_Zn25 = 3.743

# %%
test = !grep -A 1200 "\-1.564" /home/nadamski/SupLatPots/ZnO/Zn8Mg8/PBE00/DOSCAatoms = [np.array([[float(i) for i in k.split()] for k in test[S*1202:S*1202+1201]]) for S in range(33)]

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = ['green', 'blue']

E = atoms[0][:,0] -2.2549
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-4, 41], 'k-.', alpha=0.6)

ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

ax.text(-1.2, 33, r'$E_F$', color='k', fontsize=16)
plt.ylim([0, 36])

plt.savefig('/home/nadamski/SupLatPots/ZnO/Zn8Mg8/PBE00/MgO.png', bbox_inches='tight', format='png', dpi=300)


plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-5e8d9639804c> in <module>
#       5 colors = ['green', 'blue']
#       6
# ----> 7 E = atoms[0][:,0] -2.2549
#       8 for AT in range(1,17):
#       9     DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
#
# NameError: name 'atoms' is not defined

# %%
test = !grep -A 1300 "\-4.011" /home/nadamski/SupLatPots/ZnO/Zn8Mg8/HSE00/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1302:S*1302+1301]]) for S in range(33)]

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = ['green', 'blue']

E = atoms[0][:,0] -2.0914
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-4, 41], 'k-.', alpha=0.6)

plt.xlim([-6, 10])
plt.ylim([0, 36])

ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

ax.text(-1.2, 33, r'$E_F$', color='k', fontsize=16)

plt.savefig('/home/nadamski/SupLatPots/ZnO/Zn8Mg8/HSE00/MgO.png', bbox_inches='tight', format='png', dpi=300)
plt.savefig('MgO.png', bbox_inches='tight', format='png', dpi=300)


plt.show()

# %%
Mg = c_Mg_on_Zn / 3
Zn = c_Zn / 2
Ef_Mg = np.array([-8.199805339063143, -5.959834697592379])
Ef_Zn = np.array([-4.6592304088080505, -6.043707151691635])

VB_Mg = 2.054091
CB_Mg = 7.512688

VB_Zn =-0.009847
CB_Zn = 2.597465

Ef = 2.0914
a = -6.146355054611129

# %%
plt.plot(Ef_Zn+VB_Zn, [0, 8*Zn], 'b')
plt.plot(Ef_Zn+CB_Zn, [0, 8*Zn], 'b')

plt.plot(Ef_Mg+VB_Mg, [8*Zn, 8*Zn + 8*Mg],'g')
plt.plot(Ef_Mg+CB_Mg, [8*Zn, 8*Zn + 8*Mg],'g')

plt.plot([Ef + a, Ef + a], [0, 8*Zn + 8*Mg], 'k-.', alpha=0.5)

# %%
test = !grep -A 1300 "\-4.011" /home/nadamski/SupLatPots/ZnO/Zn8Mg8/HSE00/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1302:S*1302+1301]]) for S in range(33)]

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = ['green', 'blue']

E = atoms[0][:,0] -2.0914
for AT in range(1,9):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+Zn*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
    
for AT in range(9,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+Mg*(AT-9) + 8*Zn
    plt.plot(E,DOS, colors[AT < 9])
    
plt.plot(Ef_Zn+VB_Zn -Ef-a, [0, 8*Zn], 'k')
plt.plot(Ef_Zn+CB_Zn -Ef-a, [0, 8*Zn], 'k')

plt.plot(Ef_Mg+VB_Mg -Ef-a, [8*Zn, 8*Zn + 8*Mg],'k')
plt.plot(Ef_Mg+CB_Mg -Ef-a, [8*Zn, 8*Zn + 8*Mg],'k')

plt.plot([0, 0], [-4, 41], 'k-.', alpha=0.6)

#plt.xlim([-6, 10])
#plt.ylim([0, 36])

ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

ax.text(-1.2, 33, r'$E_F$', color='k', fontsize=16)

plt.savefig('/home/nadamski/SupLatPots/ZnO/Zn8Mg8/HSE00/MgO.png', bbox_inches='tight', format='png', dpi=300)


plt.show()

# %%
test = !grep -A 1300 "\-4.011" /home/nadamski/SupLatPots/ZnO/Zn8Mg8/HSE_bulk/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1302:S*1302+1301]]) for S in range(33)]

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = ['green', 'blue']

E = atoms[0][:,0] -2.6616
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-4, 41], 'k-.', alpha=0.6)

plt.xlim([-6, 10])
plt.ylim([0, 36])

ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

ax.text(-1.2, 33, r'$E_F$', color='k', fontsize=16)

plt.savefig('/home/nadamski/SupLatPots/ZnO/Zn8Mg8/HSE_bulk/MgO_bulk.png', bbox_inches='tight', format='png', dpi=300)
plt.savefig('MgO_bulk.png', bbox_inches='tight', format='png', dpi=300)


plt.show()

# %%
test = !grep -A 1300 "\-4.005" /home/nadamski/SupLatPots/ZnO/Zn8Cd8/HSE00/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1302:S*1302+1301]]) for S in range(33)]

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = ['green', 'blue']

E = atoms[0][:,0] -2.6652
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-4, 41], 'k-.', alpha=0.6)

plt.xlim([-6, 10])
plt.ylim([0, 36])

ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

ax.text(-1.2, 33, r'$E_F$', color='k', fontsize=16)

plt.savefig('/home/nadamski/SupLatPots/ZnO/Zn8Cd8/HSE00/CdO.png', bbox_inches='tight', format='png', dpi=300)


plt.show()

# %%
test = !grep -A 1300 "\-4.006" /home/nadamski/SupLatPots/ZnO/Zn8Cd8/HSE_bulk/DOSCAR
test2 = !grep -A 800 "6.405" /home/nadamski/SupLatPots/ZnO/Zn8Cd8/HSE_bulk/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1302:S*1302+1301]]) for S in range(33)]
atoms2 = [np.array([[float(i) for i in k.split()] for k in test2[S*802:S*802+801]]) for S in range(33)]

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = ['red', 'blue']

E = atoms[0][:,0] -1.9743
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
    
E = atoms2[0][:,0] -1.9743
for AT in range(1,17):
    DOS = np.sum(atoms2[AT][:,1:],1) + np.sum(atoms2[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-4, 41], 'k-.', alpha=0.6)

plt.xlim([-6, 10])
plt.ylim([0, 36])

ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

ax.text(-1.2, 33, r'$E_F$', color='k', fontsize=16)

plt.savefig('/home/nadamski/SupLatPots/ZnO/Zn8Cd8/HSE00/CdO.png', bbox_inches='tight', format='png', dpi=300)


plt.show()

# %%
atoms[1]
# Out:
# array([[-4.006e+00,  1.264e-01,  9.416e-03, ...,  7.828e-02,  1.868e-02,
#          5.475e-03],
#        [-3.998e+00,  1.226e-01,  9.141e-03, ...,  7.492e-02,  1.839e-02,
#          5.464e-03],
#        [-3.990e+00,  1.182e-01,  8.828e-03, ...,  7.142e-02,  1.811e-02,
#          5.409e-03],
#        ...,
#        [ 6.381e+00,  3.801e-02,  1.054e-01, ...,  9.099e-04,  6.030e-03,
#          7.767e-04],
#        [ 6.389e+00,  4.172e-02,  1.177e-01, ...,  8.611e-04,  6.391e-03,
#          8.511e-04],
#        [ 6.397e+00,  4.564e-02,  1.299e-01, ...,  8.267e-04,  6.735e-03,
#          9.265e-04]])

# %%
test = !grep -A 1000 "\-3.999" /home/nadamski/SupLatPots/ZnO/Zn8Ca8/HSE00/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1002:S*1002+1001]]) for S in range(33)]

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = ['green', 'blue']

E = atoms[0][:,0] -2.6636
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-4, 41], 'k-.', alpha=0.6)
plt.xlim([-6, 10])
plt.ylim([0, 36])

ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

ax.text(-1.2, 33, r'$E_F$', color='k', fontsize=16)

plt.savefig('/home/nadamski/SupLatPots/ZnO/Zn8Cd8/HSE00/CaO.png', bbox_inches='tight', format='png', dpi=300)


plt.show()

# %%
test = !grep -A 90 "\-4.128" /home/nadamski/SupLatPots/ZnO/Zn8Ca8/HSE_bulk/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*92:S*92+91]]) for S in range(33)]

fig = plt.figure(figsize=(6,4))
ax = plt.subplot(111)
colors = ['green', 'blue']

E = atoms[0][:,0] -2.5413
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-4, 41], 'k-.', alpha=0.6)
plt.xlim([-6, 10])
plt.ylim([0, 36])

ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)

ax.text(-1.2, 33, r'$E_F$', color='k', fontsize=16)

plt.savefig('/home/nadamski/SupLatPots/ZnO/Zn8Cd8/HSE00/CaO.png', bbox_inches='tight', format='png', dpi=300)


plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-15-fa1bf7553549> in <module>
#       6 colors = ['green', 'blue']
#       7
# ----> 8 E = atoms[0][:,0] -2.5413
#       9 for AT in range(1,17):
#      10     DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
#
# IndexError: too many indices for array

# %%
fig = plt.figure(figsize=(12,4)) 
ax = plt.subplot(131)


test = !grep -A 1300 "\-4.011" /home/nadamski/SupLatPots/ZnO/Zn8Mg8/HSE00/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1302:S*1302+1301]]) for S in range(33)]
colors = ['C2', 'blue']

E = atoms[0][:,0] -2.0914
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-4, 41], 'k-.', alpha=0.6)

plt.xlim([-6, 10])
plt.ylim([0, 36])

ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)
ax.text(-2, 33.5, r'$E_F$', color='k', fontsize=16)
ax.text(-6, 33, r'(a)', color='k', fontsize=20)


ax = plt.subplot(132)


test = !grep -A 1300 "\-4.005" /home/nadamski/SupLatPots/ZnO/Zn8Cd8/HSE00/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1302:S*1302+1301]]) for S in range(33)]
colors = ['deeppink', 'blue']

E = atoms[0][:,0] -2.6652
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-4, 41], 'k-.', alpha=0.6)

plt.xlim([-6, 10])
plt.ylim([0, 36])

ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
ax.text(-2, 33.5, r'$E_F$', color='k', fontsize=16)
ax.text(-6, 33, r'(b)', color='k', fontsize=20)


ax = plt.subplot(133)


test = !grep -A 1000 "\-3.999" /home/nadamski/SupLatPots/ZnO/Zn8Ca8/HSE00/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1002:S*1002+1001]]) for S in range(33)]
colors = ['dimgray', 'blue']

E = atoms[0][:,0] -2.6636
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-4, 41], 'k-.', alpha=0.6)
plt.xlim([-6, 10])
plt.ylim([0, 36])

ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)

ax.text(-2, 33.5, r'$E_F$', color='k', fontsize=16)

ax.text(-6, 33, r'(c)', color='k', fontsize=20)



plt.savefig('DOS_00_3.png', bbox_inches='tight', format='png', dpi=300)

plt.show()

# %%
fig = plt.figure(figsize=(12,4)) 
ax = plt.subplot(131)


test = !grep -A 1300 "\-4.011" /home/nadamski/SupLatPots/ZnO/Zn8Mg8/HSE_bulk/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1302:S*1302+1301]]) for S in range(33)]

colors = ['green', 'blue']

E = atoms[0][:,0] -2.6616
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-4, 41], 'k-.', alpha=0.6)

plt.xlim([-6, 10])
plt.ylim([0, 36])

ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)
ax.text(-2, 33.5, r'$E_F$', color='k', fontsize=16)
ax.text(-6, 33, r'(a)', color='k', fontsize=20)


ax = plt.subplot(132)


test = !grep -A 1300 "\-4.006" /home/nadamski/SupLatPots/ZnO/Zn8Cd8/HSE_bulk/DOSCAR
test2 = !grep -A 800 "6.405" /home/nadamski/SupLatPots/ZnO/Zn8Cd8/HSE_bulk/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1302:S*1302+1301]]) for S in range(33)]
atoms2 = [np.array([[float(i) for i in k.split()] for k in test2[S*802:S*802+801]]) for S in range(33)]

colors = ['red', 'blue']

E = atoms[0][:,0] -1.9743
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
    
E = atoms2[0][:,0] -1.9743
for AT in range(1,17):
    DOS = np.sum(atoms2[AT][:,1:],1) + np.sum(atoms2[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-4, 41], 'k-.', alpha=0.6)

plt.xlim([-6, 10])
plt.ylim([0, 36])

ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
ax.text(-2, 33.5, r'$E_F$', color='k', fontsize=16)
ax.text(-6, 33, r'(b)', color='k', fontsize=20)


ax = plt.subplot(133)


test = !grep -A 90 "\-4.128" /home/nadamski/SupLatPots/ZnO/Zn8Ca8/HSE_bulk/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*92:S*92+91]]) for S in range(33)]
colors = ['cyan', 'blue']

E = atoms[0][:,0] -2.5413
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-4, 41], 'k-.', alpha=0.6)
plt.xlim([-6, 10])
plt.ylim([0, 36])

ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)

ax.text(-2, 33.5, r'$E_F$', color='k', fontsize=16)

ax.text(-6, 33, r'(c)', color='k', fontsize=20)



plt.savefig('DOS_bulk_3.png', bbox_inches='tight', format='png', dpi=300)

plt.show()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-45478006f90f> in <module>
#      63 colors = ['cyan', 'blue']
#      64
# ---> 65 E = atoms[0][:,0] -2.5413
#      66 for AT in range(1,17):
#      67     DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
#
# IndexError: too many indices for array

# %%
fig = plt.figure(figsize=(12,4)) 
ax = plt.subplot(131)


test = !grep -A 1300 "\-4.011" /home/nadamski/SupLatPots/ZnO/Zn8Mg8/HSE00/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*1302:S*1302+1301]]) for S in range(33)]
colors = ['C2', 'blue']

E = atoms[0][:,0] -2.0914
print(E)
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-4, 41], 'k-.', alpha=0.6)

plt.xlim([-6, 10])
plt.ylim([0, 36])

ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)
ax.text(-2, 33.5, r'$E_F$', color='k', fontsize=16)
ax.text(-6, 33, r'(a)', color='k', fontsize=20)

ax = plt.subplot(132)


test = !grep -A 5000 "\-3.997" /home/nadamski/SupLatPots/ZnO/Zn8Mg8/HSE00_2/DOSCAR
atoms = [np.array([[float(i) for i in k.split()] for k in test[S*5002:S*5002+5000]]) for S in range(33)]
colors = ['C2', 'blue']
atoms[0] = atoms[0].astype('float')

E = atoms[0][:,0] -2.0914
for AT in range(1,17):
    DOS = np.sum(atoms[AT][:,1:],1) + np.sum(atoms[16+AT][:,1:],1)+2*(AT-1)
    plt.plot(E,DOS, colors[AT < 9])
plt.plot([0, 0], [-4, 41], 'k-.', alpha=0.6)

plt.xlim([-6, 10])
plt.ylim([0, 36])

ax.set_yticks([]) 
ax.set_xticklabels(ax.get_xticks(), fontsize=16) 
plt.xlabel('Energy (eV)', fontsize=16)
plt.ylabel('Density of States (a.u.)', fontsize=16)
ax.text(-2, 33.5, r'$E_F$', color='k', fontsize=16)
ax.text(-6, 33, r'(a)', color='k', fontsize=20)
# Out:
# [-6.1024 -6.0894 -6.0774 ... 10.6446 10.6566 10.6696]
# Text(-6, 33, '(a)')

# %%
for i in atoms[0]:
    print(i)
# Out:
# [ -3.997  24.63  114.   ]
# [ -3.994  24.43  114.1  ]
# [ -3.991  24.22  114.2  ]
# [ -3.988  24.    114.2  ]
# [ -3.985  23.76  114.3  ]
# [ -3.982  23.51  114.4  ]
# [ -3.979  23.25  114.4  ]
# [ -3.976  22.98  114.5  ]
# [ -3.973  22.7   114.6  ]
# [ -3.97  22.42 114.6 ]
# [ -3.967  22.13  114.7  ]
# [ -3.964  21.83  114.8  ]
# [ -3.961  21.52  114.8  ]
# [ -3.958  21.22  114.9  ]
# [ -3.955  20.91  115.   ]
# [ -3.952  20.6   115.   ]
# [ -3.949  20.29  115.1  ]
# [ -3.946  19.97  115.2  ]
# [ -3.943  19.67  115.2  ]
# [ -3.94  19.36 115.3 ]
# [ -3.937  19.06  115.3  ]
# [ -3.934  18.76  115.4  ]
# [ -3.931  18.47  115.4  ]
# [ -3.928  18.18  115.5  ]
# [ -3.925  17.9   115.5  ]
# [ -3.922  17.63  115.6  ]
# [ -3.919  17.37  115.7  ]
# [ -3.916  17.12  115.7  ]
# [ -3.913  16.87  115.8  ]
# [ -3.91  16.64 115.8 ]
# [ -3.907  16.41  115.9  ]
# [ -3.904  16.2   115.9  ]
# [ -3.901  16.    115.9  ]
# [ -3.898  15.81  116.   ]
# [ -3.895  15.63  116.   ]
# [ -3.892  15.47  116.1  ]
# ...

# %%
test
# Out:
# ['     11.00000000     -4.00000000 5001      2.09000000      1.00000000',
#  '     -4.000  0.3798E+05  0.1139E+03',
#  '     -3.997  0.2463E+02  0.1140E+03',
#  '     -3.994  0.2443E+02  0.1141E+03',
#  '     -3.991  0.2422E+02  0.1142E+03',
#  '     -3.988  0.2400E+02  0.1142E+03',
#  '     -3.985  0.2376E+02  0.1143E+03',
#  '     -3.982  0.2351E+02  0.1144E+03',
#  '     -3.979  0.2325E+02  0.1144E+03',
#  '     -3.976  0.2298E+02  0.1145E+03',
#  '     -3.973  0.2270E+02  0.1146E+03',
#  '     -3.970  0.2242E+02  0.1146E+03',
#  '     -3.967  0.2213E+02  0.1147E+03',
#  '     -3.964  0.2183E+02  0.1148E+03',
#  '     -3.961  0.2152E+02  0.1148E+03',
#  '     -3.958  0.2122E+02  0.1149E+03',
#  '     -3.955  0.2091E+02  0.1150E+03',
#  '     -3.952  0.2060E+02  0.1150E+03',
#  '     -3.949  0.2029E+02  0.1151E+03',
#  '     -3.946  0.1997E+02  0.1152E+03',
#  '     -3.943  0.1967E+02  0.1152E+03',
#  '     -3.940  0.1936E+02  0.1153E+03',
#  '     -3.937  0.1906E+02  0.1153E+03',
# ...

# %%
len(test)
# Out:
# 165066
